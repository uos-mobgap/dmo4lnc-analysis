# %% [markdown]
# # Sync IMU and MoCap
# ### Notes
#  - Fix the timestamps as the ones from the Qualisys computer are always off. Make it come from the first datapoint of the timestamp.

# %%
from pathlib import Path
import sys

parent_dir = Path.cwd().parent

if str(parent_dir) not in sys.path:
    sys.path.append(str(parent_dir))

from functions import align_imu_mocap

# %%
base_path = r"C:\Users\ac4jmi\Desktop\DMO4LNC\dmo4lnc-analysis\Dataset\CP\234\Lab\\"
align_imu_mocap(base_path, prints = True)
# Out:
# Source imu_wrist_fs: 100.0
# Source imu_waist_fs: 100.0
# Interpolated imu_wrist_fs: 100.0
# Interpolated imu_waist_fs: 100.0
# Number of NaNs = 0
# Marker start time: [['TIME_STAMP' '2026-03-13, 12:10:19.990' 6616.8531355]]
# marker_fs: 100.0
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:734, in FrameInfo.lines(self)
#     718 @cached_property
#     719 def lines(self) -> List[Union[Line, LineGap, BlankLineRange]]:
#     720     """
#     721     A list of lines to display, determined by options.
#     722     The objects yielded either have type Line, BlankLineRange
#    (...)    732     The Line objects are all within the ranges from .included_pieces.
#     733     """
# --> 734     pieces = self.included_pieces
#     735     if not pieces:
#     736         return []
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:677, in FrameInfo.included_pieces(self)
#     666 @cached_property
#     667 def included_pieces(self) -> List[range]:
#     668     """
#     669     The list of pieces (ranges of lines) to display for this frame.
#     670     Consists of .executing_piece, surrounding context pieces
#    (...)    675     Always a subset of .scope_pieces.
#     676     """
# --> 677     scope_pieces = self.scope_pieces
#     678     if not self.scope_pieces:
#     679         return []
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:617, in FrameInfo.scope_pieces(self)
#     612     return self.source.pieces
#     614 scope_start, scope_end = self.source.line_range(self.scope)
#     615 return [
#     616     piece
# --> 617     for piece in self.source.pieces
#     618     if scope_start <= piece.start and piece.stop <= scope_end
#     619 ]
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     142 if obj is None:
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:101, in Source.pieces(self)
#      96 if not self.tree:
#      97     return [
#      98         range(i, i + 1)
#      99         for i in range(1, len(self.lines) + 1)
#     100     ]
# --> 101 return list(self._clean_pieces())
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:116, in Source._clean_pieces(self)
#     112 def _clean_pieces(self) -> Iterator[range]:
#     113     pieces = self._raw_split_into_pieces(self.tree, 1, len(self.lines) + 1)
#     114     pieces = [
#     115         (start, end)
# --> 116         for (start, end) in pieces
#     117         if end > start
#     118     ]
#     120     # Combine overlapping pieces, i.e. consecutive pieces where the end of the first
#     121     # is greater than the start of the second.
#     122     # This can happen when two statements are on the same line separated by a semicolon.
#     123     new_pieces = pieces[:1]
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:168, in Source._raw_split_into_pieces(self, stmt, start, end)
#     166 for rang, group in sorted(group_by_key_func(body, self.line_range).items()):
#     167     sub_stmt = group[0]
# --> 168     for inner_start, inner_end in self._raw_split_into_pieces(sub_stmt, *rang):
#     169         if start < inner_start:
#     170             yield start, inner_start
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:166, in Source._raw_split_into_pieces(self, stmt, start, end)
#     161 for name, body in ast.iter_fields(stmt):
#     162     if (
#     163             isinstance(body, list) and body and
#     164             isinstance(body[0], (ast.stmt, ast.ExceptHandler, getattr(ast, 'match_case', ())))
#     165     ):
# --> 166         for rang, group in sorted(group_by_key_func(body, self.line_range).items()):
#     167             sub_stmt = group[0]
#     168             for inner_start, inner_end in self._raw_split_into_pieces(sub_stmt, *rang):
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:125, in group_by_key_func(iterable, key_func)
#     123 result = defaultdict(list)
#     124 for item in iterable:
# --> 125     result[key_func(item)].append(item)
#     126 return result
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\core.py:178, in Source.line_range(self, node)
#     177 def line_range(self, node: ast.AST) -> Tuple[int, int]:
# --> 178     return line_range(self.asttext(), node)
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\stack_data\utils.py:40, in line_range(atok, node)
#      38     return start, end
#      39 else:
# ---> 40     (start, _), (end, _) = atok.get_text_positions(node, padded=False)
#      41     return start, end + 1
#
# File ~\Desktop\DMO4LNC\dmo4lnc-analysis\.venv\Lib\site-packages\asttokens\asttokens.py:385, in ASTText.get_text_positions(self, node, padded)
#     381   end = (end_lineno, end_col_offset)
#     383   return start, end
# --> 385 def get_text_positions(self, node, padded):
#     386   # type: (AstNode, bool) -> Tuple[Tuple[int, int], Tuple[int, int]]
#     387   """
#     388   Returns two ``(lineno, col_offset)`` tuples for the start and end of the given node.
#     389   If the positions can't be determined, or the nodes don't correspond to any particular text,
#    (...)    394   leading whitespace if ``node`` is a multiline statement.
#     395   """
#     396   if getattr(node, "_broken_positions", None):
#     397     # This node was marked in util.annotate_fstring_nodes as having untrustworthy lineno/col_offset.
#
# KeyboardInterrupt:
